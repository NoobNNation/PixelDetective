# %% [markdown]
# # 2. Data Acquisition

# %% [markdown]
# ## 2.1 Import Libraries

# %%
import requests, os, re, json, fnmatch, math, time, random
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## 2.2 Search List Manager

# %% [markdown]
# ### 2.2.1 Create Search List Manager

# %%
class SearchManager:
    file_path = '../02. Datasets/Dataset_URLs.json'
    static_websites = ['aad.org','dermnetnz.org','reddit.com','dermcoll.edu.au','pcds.org.uk',
    'skinsight.com','sciencephoto.com','flickr.com','researchgate.net','acadderm.com',
    'aocd.org','instagram.com','facebook.com','hsc.unm.edu','link.springer.com','pharmaceutical-journal.com',
    'actasdermo.org','verywellhealth.com','mdedge.com'
    ]
    download_directory_path = '../02. Datasets/Images'
    credentials_path = '../Credentials.json'
    
    def __init__(self):
        self.search_list = self.load_search_list()
        
        # Load 1st set of keys by default
        self.load_credentials(0)

    @classmethod
    def load_search_list(cls):
        try:
            with open(cls.file_path, 'r', encoding='utf-8') as inFile:
                return json.load(inFile)
        except FileNotFoundError:
            print("File not found.")
            return []

    # Load Google Custom Search API Keys & Google Programmable Search engine ID
    def load_credentials(self, index):
        with open(self.credentials_path, 'r') as file:
            credentials = json.load(file)
            if 'Google Custom Search API' in credentials and len(credentials['Google Custom Search API']) > index:
                google_custom_search_creds = credentials['Google Custom Search API'][index]
                self.api_key = google_custom_search_creds.get('api_key')
                self.cse_id = google_custom_search_creds.get('cse_id')
            else:
                raise ValueError("Invalid credentials index or missing credentials.")

        if not self.api_key or not self.cse_id:
            raise ValueError("API key or CSE ID not found for the specified index.")
            
    class QuotaExceededException(Exception):
        """Raise exception when API quota exceeds."""
        def __init__(self, message=None):
            if message is None:
                message = "Quota limit exceeded for the day."
            super().__init__(message)
    
    def save(self):
        try:
            with open(self.file_path, 'w', encoding='utf-8') as outFile:
                json.dump(self.search_list, outFile, ensure_ascii=False, indent=4)
            print("Search list saved successfully.")
        except IOError as e:
            print(f"Error saving file: {e}")
            
    def add_image_urls(self):
        for item in self.search_list:
            languages = item['lang'].keys()
            item['imageURLs'] = {
                'site': {
                    site: {'lang': {lang: [] for lang in languages}}
                    for site in self.static_websites
                }
            }
        return self.search_list

    def add_general_sites(self):
        if not self.search_list:
            return

        # Get the current sites from the first item's imageURLs attribute
        current_sites = self.search_list[0]['imageURLs']['site'].keys()

        # Check for any new sites in static_websites that are not in current_sites
        new_sites = set(self.static_websites) - set(current_sites)
        
        if new_sites:
            for item in self.search_list:
                languages = item['lang'].keys()
                for site in new_sites:
                    item['imageURLs']['site'][site] = {'lang': {lang: [] for lang in languages}}
        return self.search_list

    def add_baidu_site(self):
        if not self.search_list:
            return

        for item in self.search_list:
            item['imageURLs']['site']['baidu.com'] = []
        return self.search_list

    def google_search_images(self, query_label, query, num_images=10, max_pages=10, img_size='', start_from=0):
        search_url = "https://www.googleapis.com/customsearch/v1"
        image_urls = []

        for page in range(max_pages):
            start_index = page * num_images + 1 + start_from
            # Limit search results to 100
            if start_index > 100:
                break

            params = {
                'q': query,
                'exactTerms':query_label,
                'cx': self.cse_id,
                'num': min(num_images, 10),  # num cannot exceed 10
                'start': start_index,
                'searchType': 'image',
                'filter': 1,
                'key': self.api_key
            }
            # Add 'imgSize' attribute only if it is provided
            if img_size:
                params['imgSize'] = img_size
            
            response = requests.get(search_url, params=params)
            if response.status_code == 429:
                error_message = response.json().get('error', {}).get('message')
                raise self.QuotaExceededException(error_message)
                
            result = response.json()
            page_urls = [item['link'] for item in result.get('items', [])]
            if not page_urls:
                # Terminate if no more results are found
                break
            image_urls.extend(page_urls)

        return image_urls

    def update_google_urls_for_item(self, item, lang_code, site, max_urls_per_site=100):
        className = item['label']
        if lang_code not in item['lang'] or site not in item['imageURLs']['site']:
            print(f"Language code '{lang_code}' or site '{site}' not found in item.")
            return
        query_label = item['lang'][lang_code]['label']
        search_query = f'"{query_label}" site:{site}'
        existing_urls_count = len(item['imageURLs']['site'][site]['lang'][lang_code])
        urls_needed = max_urls_per_site - existing_urls_count
        if urls_needed <= 0:
            print(f"Already have {max_urls_per_site} or more URLs for {lang_code} in {site}.")
            return

        # Perform the search and get image URLs
        image_urls = self.google_search_images(
            query_label,
            search_query, 
            num_images=min(urls_needed, 10), 
            max_pages=(urls_needed // 10 + 1),
            img_size='',
            start_from=existing_urls_count
        )

        # Extend imageURLs for the specified language & site
        item['imageURLs']['site'][site]['lang'][lang_code].extend(image_urls[:urls_needed])

    def get_baidu_page_URLs(self, search_term, pn):
        base_url = "https://image.baidu.com/search/acjson"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36",
            "Accept": "text/plain, */*; q=0.01",
            "Accept-Language": "en-US,en;q=0.9",
        }
        params = {
            'tn': 'resultjson_com',
            'ipn': 'rj',
            'ct': '201326592',
            'fp': 'result',
            'word': search_term,
            'queryWord': search_term,
            'cl': '2',
            'lm': '-1',
            'ie': 'utf-8',
            'oe': 'utf-8',
            'nc': '1',
            'pn': pn,
            'rn': '30'
        }
        full_url = requests.Request('GET', base_url, params=params).prepare().url
        response = requests.get(full_url, headers=headers)
        if response.status_code == 200:
            try:
                response_json = json.loads(response.text)
            except json.JSONDecodeError:
                response_json = re.sub(r'"fromPageTitle".*(?="bdSourceName")', '', response.text)
                response_json = json.loads(response_json)
            return response_json
        else:
            return f"Error: {response.status_code}"
    
    def baidu_search_images(self, search_term, pages):
        URLs = []
        for page_number in range(pages):
            pn = 30 * page_number
            response = self.get_baidu_page_URLs(search_term, pn)
            for item in response.get('data'):
                URLs.append(item.get('thumbURL', ''))
        return URLs
    
    def update_baidu_urls_for_item(self, item, chinese_searchTerm, pages):
        URLs = self.baidu_search_images(chinese_searchTerm, pages)
        item['imageURLs']['site']['baidu.com'].extend(URLs)

# Instantiate SearchManager
searchManager = SearchManager()

# %% [markdown]
# ### 2.2.2 Format Search List - Once ONLY

# %%
searchManager.add_image_urls()
searchManager.save()

# %% [markdown]
# ### 2.2.3 Add New Sites to each class

# %%
# General sites
searchManager.add_general_sites()
searchManager.save()
# Out:
# Search list saved successfully.

# %%
# 'baidu.com' site only
searchManager.add_baidu_site()
searchManager.save()
# Out:
# Search list saved successfully.

# %% [markdown]
# ### 2.2.4 Bulk <u>Fetch Image URLs</u>: Using Dataset_URLs.json

# %% [markdown]
# #### 2.2.4.1 Google Search Engine - Utilise Custom Search API

# %%
# Specify which API Key to use
searchManager.load_credentials(0)

# Specify range of items to process
start_index = 0
end_index = 236

# Iterate over the specified range of items in the search list
for i in range(start_index, end_index + 1):
    try:
        item = searchManager.search_list[i]
        lang_code, site = 'en', 'mdedge.com'
        max_urls_per_site = 100
        searchManager.update_google_urls_for_item(item, lang_code, site, max_urls_per_site=max_urls_per_site)
        print(f"Successfully processed item {i}")

    except IndexError:
        print(f"Index {i} is out of range for the search list.")
        
    except searchManager.QuotaExceededException as e:
        print(f"Quota limit reached at (Index {i}).\n{e}")
        print("Terminated loop...")
        # Exit the loop as quota limit is reached
        break
        
    except Exception as e:
        print(f"An error occurred while processing item at (Index {i}): {e}")

# Save changes to file
searchManager.save()
# Out:
# Successfully processed item 222
# Successfully processed item 223
# Skipped Class_Exclusion_List: Pemphigoid, Benign Mucous Membrane
# Successfully processed item 224
# Successfully processed item 225
# Skipped Class_Exclusion_List: Pemphigus
# Successfully processed item 226
# Successfully processed item 227
# Skipped Class_Exclusion_List: Sweat Gland Neoplasms
# Successfully processed item 228
# Successfully processed item 229
# Successfully processed item 230
# Successfully processed item 231
# Skipped Class_Exclusion_List: Pressure Ulcer
# Successfully processed item 232
# Skipped Class_Exclusion_List: Sweating, Gustatory
# Successfully processed item 233
# Skipped Class_Exclusion_List: Hypohidrosis
# Successfully processed item 234
# Successfully processed item 235
# Successfully processed item 236
# Search list saved successfully.

# %% [markdown]
# #### 2.2.4.2 Baidu Search Engine - Utilise Data Scraping Techniques

# %%
# Specify range of items to process
start_index = 0
end_index = 236
page_items = 30

# Iterate over the specified range of items in the search list
for i in range(start_index, end_index + 1):
    try:
        item = searchManager.search_list[i]
        chinese_searchTerm = None
        if 'zh' in item['lang']:
            chinese_searchTerm = item['lang']['zh'].get('label')
        if chinese_searchTerm:
            pages = math.ceil(page_items / 30)
            searchManager.update_baidu_urls_for_item(item, chinese_searchTerm, pages)
            print(f"Successfully processed item {i} {item['label']}")

            # Add a random pause between 4-6 seconds
            time.sleep(random.uniform(4, 6))
    
    except IndexError:
        print(f"Index {i} {item['label']} is out of range for the search list.")
        
    except Exception as e:
        print(f"An error occurred while processing item at (Index {i} {item['label']}): {e}")

# Save changes to file
searchManager.save()
# Out:
# Successfully processed item 2 Chloracne
# Successfully processed item 21 Dermatitis Herpetiformis
# Successfully processed item 22 Dermatitis, Atopic
# Successfully processed item 23 Dermatitis, Photoallergic
# Successfully processed item 27 Dermatitis, Occupational
# Successfully processed item 28 Dermatitis, Exfoliative
# Successfully processed item 30 Dermatitis, Seborrheic
# Successfully processed item 33 Erythema Nodosum
# Successfully processed item 36 Serum Sickness
# Successfully processed item 37 Stevens-Johnson Syndrome
# Successfully processed item 38 Eczema, Dyshidrotic
# Successfully processed item 39 Tinea cruris
# Successfully processed item 41 Radiodermatitis
# Successfully processed item 42 Dermatomyositis
# Successfully processed item 43 Erythema Ab Igne
# Successfully processed item 44 Erythema Chronicum Migrans
# Successfully processed item 51 Tinea Pedis
# Successfully processed item 56 Alopecia Areata
# Successfully processed item 63 Keratoacanthoma
# Successfully processed item 66 Darier Disease
# Successfully processed item 76 Keratosis, Actinic
# Successfully processed item 77 Keratosis, Seborrheic
# Successfully processed item 79 Porokeratosis
# Successfully processed item 87 Nails, Ingrown
# Successfully processed item 88 Onycholysis
# Successfully processed item 89 Onychomycosis
# Successfully processed item 90 Steatocystoma Multiplex
# Successfully processed item 96 Necrolytic Migratory Erythema
# Successfully processed item 100 Sunburn
# Successfully processed item 102 Xeroderma Pigmentosum
# Successfully processed item 104 Cafe-au-Lait Spots
# Successfully processed item 105 Acanthosis Nigricans
# Successfully processed item 106 LEOPARD Syndrome
# Successfully processed item 111 Vitiligo
# Successfully processed item 115 Pruritus Ani
# Successfully processed item 117 Ecthyma
# Successfully processed item 118 Pyoderma Gangrenosum
# Successfully processed item 140 Port-Wine Stain
# Successfully processed item 153 Porphyria Cutanea Tarda
# Successfully processed item 156 Porphyria, Variegate
# Successfully processed item 168 Tinea Versicolor
# Successfully processed item 172 Erysipelas
# Successfully processed item 175 Hidradenitis Suppurativa
# Successfully processed item 178 Carbuncle
# Successfully processed item 179 Impetigo
# Successfully processed item 184 Larva Migrans
# Successfully processed item 189 Scabies
# An error occurred while processing item at (Index 190 Herpes Labialis): Invalid control character at: line 28 column 1144 (char 65364)
# Successfully processed item 192 Molluscum Contagiosum
# Successfully processed item 202 Pityriasis Rosea
# Successfully processed item 203 Pityriasis Rubra Pilaris
# Successfully processed item 204 Arthritis, Psoriatic
# Successfully processed item 221 Blister
# Successfully processed item 225 Pemphigoid, Bullous
# Successfully processed item 236 Xanthogranuloma, Juvenile
# Search list saved successfully.

# %% [markdown]
# ## 2.3 Download Manager

# %% [markdown]
# ### 2.3.1 Create Custom Download Functions for specific Data Sources

# %% [markdown]
# #### 2.3.1.1 Instagram URLs

# %%
def fetch_instagram_urls(shortcode):
    base_url = "https://www.instagram.com/graphql/query/"
    query_hash = "b3055c01b4b222b8a47dc12b090e4e64"
    variables = {"shortcode": shortcode}
    full_url = f"{base_url}?query_hash={query_hash}&variables={json.dumps(variables)}"
    response = requests.get(full_url)
    data_json = json.loads(response.content.decode('utf-8'))
    urls = []
    if 'data' in data_json and 'shortcode_media' in data_json['data']:
        media = data_json['data']['shortcode_media']
        if 'edge_sidecar_to_children' in media:
            edges = media['edge_sidecar_to_children']['edges']
            for edge in edges:
                node = edge['node']
                if 'display_url' in node:
                    urls.append(node['display_url'])
    return urls

# %%
# Instagram
def download_instagram_images(url, file_save_path):
    try:
        initial_response = requests.get(url)
        initial_response.raise_for_status()
        soup = BeautifulSoup(initial_response.content, 'html.parser')
        link_tags = soup.find_all('link')
        shortcode = None
        for tag in link_tags:
            href = tag.get('href')
            if href:
                match = re.search(r'%2Fp%2F([\w-]+)%2F', href)
                if match:
                    shortcode = match.group(1)
                    break
        downloadURLs = fetch_instagram_urls(shortcode)
        for i, URL in enumerate(downloadURLs):
            img_response = requests.get(URL)
            img_response.raise_for_status()
            with open(file_save_path + f"_{i}.jpg" , 'wb') as file:
                file.write(img_response.content)
    
    except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred: {err}")
    except requests.exceptions.RequestException as err:
        print(f"Error occurred during requests: {err}")
    except ValueError as err:
        print(err)

# %% [markdown]
# #### 2.3.1.2 Facebook URLs

# %%
# Facebook
def download_facebook_image(url, file_save_path):
    try:
        initial_response = requests.get(url)
        initial_response.raise_for_status()
        soup = BeautifulSoup(initial_response.content, 'html.parser')
        meta_refresh = soup.find('meta', attrs={'http-equiv': 'refresh'})
        if not meta_refresh:
            raise ValueError("No redirect URL found in the meta tag")
        redirect_url = meta_refresh['content'].split('url=')[1]
        response = requests.get(redirect_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        og_image = soup.find('meta', property='og:image')
        if not og_image or not og_image.get('content'):
            raise ValueError("Image URL not found")
        image_url = og_image['content']
        img_response = requests.get(image_url)
        img_response.raise_for_status()
        with open(file_save_path + ".jpg", 'wb') as file:
            file.write(img_response.content)
    
    except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred: {err}")
    except requests.exceptions.RequestException as err:
        print(f"Error occurred during requests: {err}")
    except ValueError as err:
        print(err)

# %% [markdown]
# ### 2.3.2 Create Download Manager

# %%
class DownloadManager:
    def __init__(self, download_directory_path='../02. Datasets/Images'):
        self.download_directory_path = download_directory_path

    def download_google_urls_for_item(self, item, lang_code, site):
        if lang_code not in item['lang'] or site not in item['imageURLs']['site']:
            print(f"Language code '{lang_code}' or site '{site}' not found in item.")
            return

        label = item['label']
        image_urls = item['imageURLs']['site'][site]['lang'][lang_code]

        # Create a sub-directory for the label
        label_directory = os.path.join(self.download_directory_path, label)
        if not os.path.exists(label_directory):
            os.makedirs(label_directory)

        for i, url in enumerate(image_urls):
            # Construct the file name with label/site_lang_index format
            file_name = f"{site}_{lang_code}_{i}"
            file_path = os.path.join(label_directory, file_name)

            try:
                # Only works for 'Facebook' URLs
                if site == 'facebook.com':
                    download_facebook_image(url, file_path)
                # Only works for 'Instagram' URLs
                elif site =='instagram.com':
                    download_instagram_images(url, file_path)
                # Works for ALL other URLs         
                else:
                    response = requests.get(url)
                    if response.status_code == 200:
                        with open(file_path, 'wb') as f:
                            f.write(response.content)
                    else:
                        print(f"Failed to download image from {url} with status code {response.status_code}")
                    
            except Exception as e:
                print(f"An error occurred while downloading {url}: {e}")

    def download_baidu_urls_for_item(self, item):
        site = 'baidu.com'
        lang_code ='zh'
        label = item['label']
        image_urls = item['imageURLs']['site'][site]

        # Terminate if image_urls is empty
        if (len(image_urls) < 1):
            return

        label_directory = os.path.join(self.download_directory_path, label)
        if not os.path.exists(label_directory):
            os.makedirs(label_directory)

        for i, url in enumerate(image_urls):
            if url:
                file_name = f"{site}_{lang_code}_{i}"
                if '&f=JPEG' in url:
                    file_extension = '.jpg'
                elif '&f=PNG' in url:
                    file_extension = '.png'
                else:
                    # Default file extension
                    file_extension = '.jpg'
                file_name_with_extension = file_name + file_extension
                file_path = os.path.join(label_directory, file_name_with_extension)
                try:
                    response = requests.get(url)
                    if response.status_code == 200:
                        with open(file_path, 'wb') as f:
                            f.write(response.content)
                    else:
                        print(f"Failed to download image from {url} with status code {response.status_code}")
                    time.sleep(1)
                except Exception as e:
                    print(f"An error occurred while downloading {url}: {e}")
    
    def download_images(self, image_urls, save_folder):
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)
        start_index = self.find_next_image_index(save_folder)
        for i, url in enumerate(image_urls, start=start_index):
            try:
                response = requests.get(url)
                if response.status_code == 200:
                    with open(os.path.join(save_folder, f'{i}'), 'wb') as f:
                        print(response)
                        f.write(response.content)
            except Exception as e:
                print(f"An error occurred while downloading {url}: {e}")

    def find_next_image_index(self, save_folder):
        """Find next available image index in the folder"""
        existing_files = os.listdir(save_folder)
        max_index = -1
        for file in existing_files:
            match = re.match(r"(\d+)\.jpg", file)
            if match:
                index = int(match.group(1))
                max_index = max(max_index, index)
        return max_index + 1

downloadManager = DownloadManager()

# %% [markdown]
# ### 2.3.3 Bulk <u>Download Images from URLs</u>: Using Dataset_URLs.json

# %% [markdown]
# #### 2.3.3.1 Google Search Engine URLs

# %%
downloadCompleted = []

for site in filter(lambda site: site not in downloadCompleted, searchManager.static_websites):
    print("="*100)
    print(f"Starting downloads for: {site}...")
    print("="*100)
    
    # Specify range of items to download
    start_index = 0
    end_index = 236
    
    # Iterate over the specified range of items in the search list
    for i in range(start_index, end_index + 1):
        try:
            # Access the item at the current index
            item = searchManager.search_list[i]
    
            # Specify the language code & site
            lang_code = 'en'
    
            # Download image URLs for the current item
            downloadManager.download_google_urls_for_item(item, lang_code, site)
    
        except IndexError:
            print(f"Index {i} is out of range in the search list")
        except Exception as e:
            print(f"An error occurred while downloading images for class {i}: {e}")
    print("="*100)
    print(f"Completed downloads for: {site}")
    print("="*100)
    downloadCompleted.append(site)
# Out:
# ====================================================================================================
# Starting downloads for: flickr.com...
# ====================================================================================================
# Failed to download image from https://live.staticflickr.com/65535/53042802574_7be7797eaf.jpg
# Failed to download image from https://live.staticflickr.com/65535/52715645732_2521d62c18_n.jpg
# Failed to download image from https://live.staticflickr.com/65535/51096894715_9c0110b852_z.jpg
# Failed to download image from https://live.staticflickr.com/65535/51087999716_0922e78717.jpg
# Failed to download image from https://live.staticflickr.com/65535/51096169369_976ab2d415_n.jpg
# Failed to download image from https://live.staticflickr.com/5100/5408054914_69f4ec3946_w.jpg
# ====================================================================================================
# Completed downloads for: flickr.com
# ====================================================================================================
# ====================================================================================================
# Starting downloads for: researchgate.net...
# ====================================================================================================
# Failed to download image from https://www.researchgate.net/publication/236929625/figure/fig13/AS:393138054156288@1470742824096/Acne-keloidalis-nuchae-AKN-a-Mild-moderate-AKN-with-numerous-firm-follicular-papules.png
# Failed to download image from https://www.researchgate.net/publication/317150825/figure/fig4/AS:498278492852225@1495810259024/Acne-keloidalis-nuchae-Papules-and-hypertrophic-scars-are-noticed-on-the-occipital.png
# Failed to download image from https://www.researchgate.net/profile/Rodney-Sinclair/publication/236929625/figure/fig13/AS:393138054156288@1470742824096/Acne-keloidalis-nuchae-AKN-a-Mild-moderate-AKN-with-numerous-firm-follicular-papules_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/321817295/figure/fig2/AS:571663000576000@1513306488273/Clinical-features-of-acne-keloidalis-nuchae-AKN-in-17-Korean-patients-Follicular_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig2/AS:618994453196801@1524591186774/Acne-keloidalis-plaque-form-with-secondary-infection.png
# Failed to download image from https://www.researchgate.net/publication/343341390/figure/fig1/AS:11431281173846288@1689060106967/Acne-keloidalis-nuchae-and-acanthosis-nigricans-of-varying-severity.png
# Failed to download image from https://www.researchgate.net/publication/270895172/figure/fig1/AS:1159225392791552@1653392279441/Acne-keloidalis-nuchae-of-the-occipital-scalp-after-failed-CO2-laser-treatment-and.png
# Failed to download image from https://www.researchgate.net/publication/321817295/figure/fig3/AS:571662999486464@1513306488401/Histological-features-of-acne-keloidalis-nuchae-AKN-in-17-Korean-patients-Excised-AKN.png
# Failed to download image from https://www.researchgate.net/publication/272810583/figure/fig1/AS:11431281102420934@1669460177617/A-Vertex-of-the-scalp-with-scarring-alopecia-and-tufted-folliculitis-B-Acne-keloidalis_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/270895172/figure/fig1/AS:1159225392791552@1653392279441/Acne-keloidalis-nuchae-of-the-occipital-scalp-after-failed-CO2-laser-treatment-and_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Filiz-Canpolat/publication/317150825/figure/fig4/AS:498278492852225@1495810259024/Acne-keloidalis-nuchae-Papules-and-hypertrophic-scars-are-noticed-on-the-occipital_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/272810583/figure/fig1/AS:11431281102420934@1669460177617/A-Vertex-of-the-scalp-with-scarring-alopecia-and-tufted-folliculitis-B-Acne-keloidalis.png
# Failed to download image from https://www.researchgate.net/publication/321817295/figure/fig2/AS:571663000576000@1513306488273/Clinical-features-of-acne-keloidalis-nuchae-AKN-in-17-Korean-patients-Follicular.png
# Failed to download image from https://www.researchgate.net/publication/343341390/figure/fig1/AS:11431281173846288@1689060106967/Acne-keloidalis-nuchae-and-acanthosis-nigricans-of-varying-severity_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/242018147/figure/fig1/AS:341538665189378@1458440571872/A-patient-with-keloidal-papules-and-plaques-on-the-nuchal-scalp-folliculitis-keloidalis.png
# Failed to download image from https://www.researchgate.net/publication/362258130/figure/fig5/AS:1182648303140882@1658976736562/CVG-and-localized-AKN-plaque-confined-to-the-nape-area-patient-4-with-CVG-that-preceded.png
# Failed to download image from https://www.researchgate.net/publication/270895172/figure/fig3/AS:1159225392807937@1653392279519/Post-NdYAG-and-diode-laser-therapy-the-lesion-shows-good-resolution_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig2/AS:618994453196801@1524591186774/Acne-keloidalis-plaque-form-with-secondary-infection_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/325134749/figure/fig1/AS:704983230070785@1545092508548/A-35-year-old-AKN-male-patient-with-numerous-papules-and-plaques-on-neck-showing.png
# Failed to download image from https://www.researchgate.net/publication/362258130/figure/fig5/AS:1182648303140882@1658976736562/CVG-and-localized-AKN-plaque-confined-to-the-nape-area-patient-4-with-CVG-that-preceded_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig6/AS:618994453184513@1524591186906/Occurrence-of-acne-keloidalis-and-folliculitis-decalvans.png
# Failed to download image from https://www.researchgate.net/publication/321817295/figure/tbl1/AS:670551957856265@1536883453350/Clinical-features-of-17-Korean-men-with-acne-keloidalis-nuchae.png
# Failed to download image from https://www.researchgate.net/publication/373408636/figure/fig2/AS:11431281183834436@1693055872807/A-Posterior-view-of-a-patient-with-histopathologically-proven-diagnosis-of-AKN-in-the.png
# Failed to download image from https://www.researchgate.net/publication/333213040/figure/fig2/AS:784230497923072@1563986529138/examples-of-Bat-excision-and-SiH-procedure-a-Patient-1-a-Hispanic-man-age-59-years.ppm
# Failed to download image from https://www.researchgate.net/profile/Rodney-Sinclair/publication/23964947/figure/fig16/AS:282659256324099@1444402626228/Lichen-planopilaris-variants-a-Band-like-recession-of-frontal-hairline-in-frontal_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Hend-Gamil/publication/325134749/figure/fig1/AS:704983230070785@1545092508548/A-35-year-old-AKN-male-patient-with-numerous-papules-and-plaques-on-neck-showing_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/321817295/figure/fig3/AS:571662999486464@1513306488401/Histological-features-of-acne-keloidalis-nuchae-AKN-in-17-Korean-patients-Excised-AKN_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/333213040/figure/fig2/AS:784230497923072@1563986529138/examples-of-Bat-excision-and-SiH-procedure-a-Patient-1-a-Hispanic-man-age-59-years_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/354798182/figure/fig3/AS:1071395450654720@1632451989392/A-65-year-old-male-with-history-of-AKN-for-at-least-9-years-BMI-27-kg-m-2-An-18-A-8-cm.png
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig5/AS:618994453205005@1524591186876/Huge-keloidal-lesion-in-nuchal-and-occipital-region-which-recurred-after-cryotherapy.png
# Failed to download image from https://www.researchgate.net/publication/354798182/figure/fig5/AS:1071395450650624@1632451989679/Pathology-assessment-of-case-No-1-A-Cross-section-of-surgical-specimen-Multiple_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/333853680/figure/fig5/AS:771185566576645@1560876375752/Case-1-before-A-and-6-months-after-B-4-sessions-of-ND-YAG-laser-treatments-Shows.png
# Failed to download image from https://www.researchgate.net/publication/333853680/figure/fig1/AS:771185566560256@1560876375150/Schematic-explaining-why-a-2-mm-vertical-height-limit-for-AKN-lesions-is-preferred-for_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/330069456/figure/fig1/AS:710321157193728@1546365169422/Photograph-of-the-lesion-at-the-first-presentation-a-Extensive-AKN-associated-alopecia_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/333853680/figure/fig2/AS:771185566576641@1560876375246/A-Level-III-candidacy-This-classification-describes-a-patient-whose-predominant-lesions_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig1/AS:618994453209090@1524591186745/Papules-of-varying-sizes-on-nuchal-and-occipital-area_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/333853680/figure/fig4/AS:771185566576644@1560876375556/Case-2-before-A-and-1-year-after-B-5-sessions-of-ND-YAG-laser-treatments.png
# Failed to download image from https://www.researchgate.net/publication/343618292/figure/fig1/AS:11431281079544738@1660735153395/AKN-clinical-presentation-Initial-alopecia-with-follicular-erythematous-papules-a_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/272810583/figure/fig2/AS:11431281102400909@1669460177968/A-Millimetric-follicular-papules-affecting-the-lateral-eyebrows-and-face-B-Keratosis.png
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig5/AS:618994453205005@1524591186876/Huge-keloidal-lesion-in-nuchal-and-occipital-region-which-recurred-after-cryotherapy_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/363389976/figure/fig1/AS:11431281092969280@1667070820117/a-Face-and-trunk-lesions-and-b-Scalp-lesions-in-a-patient-of-pemphigus-vulgaris-before_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/308399515/figure/fig7/AS:962814432776199@1606564257916/Some-keloids-of-our-patients-which-located-in-different-sites-and-caused-by-different.gif
# Failed to download image from https://www.researchgate.net/publication/23964947/figure/fig13/AS:282659214381061@1444402616171/Acne-keloidalis-nuchae-AKN-a-Mild-moderate-AKN-with-numerous-firm-follicular-papules.png
# Failed to download image from https://www.researchgate.net/profile/Filiz-Canpolat/publication/317150825/figure/fig6/AS:498278498537472@1495810259219/Schematic-representation-of-life-cycle-of-head-louse_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/317150825/figure/fig3/AS:498278492012545@1495810258929/Acne-keloidalis-nuchae-Papules-are-seen-below-the-hairline.png
# Failed to download image from https://www.researchgate.net/publication/373408636/figure/fig2/AS:11431281183834436@1693055872807/A-Posterior-view-of-a-patient-with-histopathologically-proven-diagnosis-of-AKN-in-the_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/333213040/figure/fig3/AS:784230497935360@1563986529292/example-of-delayed-stretched-scar-a-Patient-4-4-weeks-after-debridement-of-mature_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/347589936/figure/fig1/AS:1021554402025472@1620568957018/A-Follicular-pustules-and-crusted-papules-on-the-posterior-neck-and-occipital-scalp-of.png
# Failed to download image from https://www.researchgate.net/publication/362258130/figure/fig1/AS:1182648303128576@1658976736177/CVG-and-widespread-AKN-papular-lesions-patient-1-with-CVG-onset-within-two-years-of-AKN.png
# An error occurred while downloading x-raw-image:///ab09b4e9ec4585f43a67d004b86bb1f4e436ae499d04599861e5f3e9e42c0dd9: No connection adapters were found for 'x-raw-image:///ab09b4e9ec4585f43a67d004b86bb1f4e436ae499d04599861e5f3e9e42c0dd9'
# Failed to download image from https://www.researchgate.net/publication/332442994/figure/fig6/AS:748290513580032@1555417769464/Treatment-algorithm-for-PFB-Reprinted-from-Coley-MK-Kelly-Alexis-AF-Pseudofolliculitis.png
# Failed to download image from https://www.researchgate.net/publication/323330655/figure/fig1/AS:596684539174912@1519272088454/Facial-disfigurement-from-coccidioides-infection_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/270895172/figure/fig3/AS:1159225392807937@1653392279519/Post-NdYAG-and-diode-laser-therapy-the-lesion-shows-good-resolution.png
# Failed to download image from https://www.researchgate.net/publication/359809608/figure/fig1/AS:1142527189106692@1649411117828/ertex-of-the-head-of-the-patient-from-a-previously-authored-study-Images-of-the-top-of.png
# Failed to download image from https://www.researchgate.net/publication/23560542/figure/tbl1/AS:643161877651464@1530353149943/Differential-diagnosis-of-keloid.png
# Failed to download image from https://www.researchgate.net/profile/Filiz-Canpolat/publication/317150825/figure/fig1/AS:498278492012544@1495810258776/Cicatricial-alopecia-with-tufted-folliculitis_Q320.jpg
# An error occurred while downloading x-raw-image:///6130a1d6d5e5df2543f5d36afca10c153add8d92fe883937c674ea28a0613614: No connection adapters were found for 'x-raw-image:///6130a1d6d5e5df2543f5d36afca10c153add8d92fe883937c674ea28a0613614'
# Failed to download image from https://www.researchgate.net/publication/330069456/figure/fig1/AS:710321157193728@1546365169422/Photograph-of-the-lesion-at-the-first-presentation-a-Extensive-AKN-associated-alopecia.png
# Failed to download image from https://www.researchgate.net/publication/351444331/figure/fig1/AS:1024594324504577@1621293731979/A-Before-treatment-B-After-2-months-of-therapy-showing-partial-hair-regrowth.png
# Failed to download image from https://www.researchgate.net/profile/Harshwardhan-Bahirat/publication/341115840/figure/fig1/AS:887271960100864@1588553528757/a-Tumor-like-swelling-on-the-nape-of-neck-b-Elongated-swelling-with-irregular_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/311859953/figure/fig1/AS:618994453209090@1524591186745/Papules-of-varying-sizes-on-nuchal-and-occipital-area.png
# Failed to download image from https://www.researchgate.net/publication/333213040/figure/fig5/AS:784230497939458@1563986529750/example-of-post-operative-hypertrophic-scarring-Patient-2-showing-formation-of-an-M.png
# Failed to download image from https://www.researchgate.net/publication/354798182/figure/fig2/AS:1071395450671104@1632451989066/Post-excisional-course-A-Postoperative-day-4-first-postoperative-assessment-in.png
# Failed to download image from https://www.researchgate.net/publication/258835833/figure/fig1/AS:297092472950784@1447843773422/Keloidal-papules-on-the-nape-of-neck.png
# Failed to download image from https://www.researchgate.net/publication/354798182/figure/fig3/AS:1071395450654720@1632451989392/A-65-year-old-male-with-history-of-AKN-for-at-least-9-years-BMI-27-kg-m-2-An-18-A-8-cm_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Salvador-Diaz-Cano/publication/230614244/figure/fig2/AS:267715575283734@1440839775177/Large-proliferative-plaque-of-keloids-on-a-the-right-and-b-the-left-side-of-the-face_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/270895172/figure/fig2/AS:1159225392799750@1653392279482/Histological-examination-showing-the-skin-with-orthokeratosis-and-with-increased_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/335345675/figure/fig5/AS:845109495070722@1578501213588/Seborrheic-dermatitis-Seborrheic-dermatitis-associated-with-scaly-hypopigmented-and.png
# An error occurred while downloading x-raw-image:///402b0dba269c929a240b0b793fccf893734e50cdbaa1e19e6f025dc8f83e34ef: No connection adapters were found for 'x-raw-image:///402b0dba269c929a240b0b793fccf893734e50cdbaa1e19e6f025dc8f83e34ef'
# Failed to download image from https://www.researchgate.net/profile/Nonhlanhla-Khumalo-2/publication/242018147/figure/fig1/AS:341538665189378@1458440571872/A-patient-with-keloidal-papules-and-plaques-on-the-nuchal-scalp-folliculitis-keloidalis_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/359809608/figure/fig1/AS:1142527189106692@1649411117828/ertex-of-the-head-of-the-patient-from-a-previously-authored-study-Images-of-the-top-of_Q320.jpg
# An error occurred while downloading x-raw-image:///dc005ae30aee0808bc3a0fab6bd3d5f5e5620a524f3f72dc6c4c8b436f1cf25d: No connection adapters were found for 'x-raw-image:///dc005ae30aee0808bc3a0fab6bd3d5f5e5620a524f3f72dc6c4c8b436f1cf25d'
# Failed to download image from https://www.researchgate.net/publication/333213040/figure/fig3/AS:784230497935360@1563986529292/example-of-delayed-stretched-scar-a-Patient-4-4-weeks-after-debridement-of-mature.ppm
# Failed to download image from https://www.researchgate.net/publication/23717242/figure/fig1/AS:276854729658368@1443018719301/Red-scaly-patches-of-the-forehead-left-temple-and.png
# Failed to download image from https://www.researchgate.net/publication/333853680/figure/fig4/AS:771185566576644@1560876375556/Case-2-before-A-and-1-year-after-B-5-sessions-of-ND-YAG-laser-treatments_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Hend-Gamil/publication/325134749/figure/fig2/AS:704983230054402@1545092508627/A-40-year-old-AKN-male-patient-with-papules-and-plaques-on-nape-of-the-neck-showing_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/373408636/figure/fig1/AS:11431281183842529@1693055872580/A-Posterior-view-of-a-patient-with-histopathologically-proven-diagnosis-of-AKN-in-the_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/328637647/figure/fig3/AS:696565417123842@1543085545863/Eruptive-xanthomas-with-chylomicronemia-a-Flat-yellowish-plaques-b-Dermoscopy-with.jpg
# Failed to download image from https://www.researchgate.net/publication/272810583/figure/fig2/AS:11431281102400909@1669460177968/A-Millimetric-follicular-papules-affecting-the-lateral-eyebrows-and-face-B-Keratosis_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/338976020/figure/fig2/AS:855437968670720@1580963713116/Improvement-of-central-centrifugal-cicatricial-alopecia-after-application-of-topical.png
# Failed to download image from https://www.researchgate.net/publication/351500480/figure/fig1/AS:1024629812502528@1621302192543/Progression-of-androgenic-alopecia-The-hair-follicles-are-miniaturized-due-the-increased.png
# Failed to download image from https://www.researchgate.net/publication/334420836/figure/fig1/AS:779880216162305@1562949341886/Acne-conglobata-lesions-with-pronounced-scarring-on-the-face-A-B-and-on-the-trunk-C.png
# Failed to download image from https://www.researchgate.net/publication/335098899/figure/fig1/AS:11431281172827726@1688664458127/Acne-conglobata-patient-at-baseline-before-treatment-displaying-severe-papules.png
# Failed to download image from https://www.researchgate.net/publication/332872748/figure/fig1/AS:894631063584768@1590308075495/Acne-conglobata-on-the-face-of-patient-1-with-SA-PHO-syndrome-Figure-2-Acne-conglobata.png
# Failed to download image from https://www.researchgate.net/profile/Marija-Jelusic/publication/332872748/figure/fig1/AS:894631063584768@1590308075495/Acne-conglobata-on-the-face-of-patient-1-with-SA-PHO-syndrome-Figure-2-Acne-conglobata_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/10917807/figure/fig11/AS:667085923418114@1536057086064/Acne-conglobata-in-an-18-year-old-male-patient-before-left-and-after-a-6month-treatment.jpg
# Failed to download image from https://www.researchgate.net/publication/10917809/figure/fig8/AS:394429870428174@1471050817410/Acne-conglobata-in-an-18-year-old-male-patient-before-left-and-after-a-6-month.png
# Failed to download image from https://www.researchgate.net/profile/Bodo-Melnik/publication/6529492/figure/fig1/AS:272593294983176@1442002714272/Acne-conglobata-induced-by-anabolic-androgenic-steroids.png
# Failed to download image from https://www.researchgate.net/publication/357842459/figure/fig2/AS:1132768247463937@1647084404881/Clinical-features-of-patients-with-syndromic-hidradenitis-suppurativa-HS-a-b-Axillary.png
# Failed to download image from https://www.researchgate.net/publication/332541583/figure/fig1/AS:768657722454024@1560273690897/A-Hidradenitis-suppurativa-on-the-patients-back-B-Dissecting-cellulitis-of-the.png
# Failed to download image from https://www.researchgate.net/publication/335098899/figure/fig1/AS:11431281172827726@1688664458127/Acne-conglobata-patient-at-baseline-before-treatment-displaying-severe-papules_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Elizabeth-Eady/publication/10917809/figure/fig8/AS:394429870428174@1471050817410/Acne-conglobata-in-an-18-year-old-male-patient-before-left-and-after-a-6-month_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/324196276/figure/fig3/AS:611779038167041@1522870897212/et-8-Acne-nodulokystique-conglobata-grave.png
# Failed to download image from https://www.researchgate.net/publication/334420836/figure/fig1/AS:779880216162305@1562949341886/Acne-conglobata-lesions-with-pronounced-scarring-on-the-face-A-B-and-on-the-trunk-C_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Goekce-Kurmus/publication/324532340/figure/fig1/AS:615750364577792@1523817735093/AC-usually-presents-as-numerous-comedones-cys-c-nodules-papules-pustules_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/26659261/figure/fig3/AS:667218908041227@1536088792795/Acne-conglobata-on-the-back-of-a-man.png
# Failed to download image from https://www.researchgate.net/publication/324532340/figure/fig1/AS:615750364577792@1523817735093/AC-usually-presents-as-numerous-comedones-cys-c-nodules-papules-pustules.png
# Failed to download image from https://www.researchgate.net/publication/6508933/figure/fig1/AS:601666877411350@1520459970614/Gluteal-region-with-multiple-nodular-lesions-and-scarring-areas-Fig-2-MRI-a-left.png
# Failed to download image from https://www.researchgate.net/publication/366329010/figure/fig3/AS:11431281124853999@1678121541624/Cutaneous-signs-of-SAPHO-and-PFAPA-a-SAPHO-acne-fulminans-on-the-upper-trunk-A-and.ppm
# Failed to download image from https://www.researchgate.net/profile/Bodo-Melnik/publication/6529492/figure/fig1/AS:272593294983176@1442002714272/Acne-conglobata-induced-by-anabolic-androgenic-steroids_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Andreas-Arnold-7/publication/324196276/figure/fig3/AS:611779038167041@1522870897212/et-8-Acne-nodulokystique-conglobata-grave_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/230671209/figure/tbl1/AS:601620823937052@1520448990652/Differential-diagnosis-of-acne-fulminans-rosacea-fulminans-and-acne-conglobata.png
# Failed to download image from https://www.researchgate.net/publication/259805406/figure/fig2/AS:282020128280589@1444250246776/Acne-fulminans-Initial-presentation-with-draining-pustules-and-crusted-papules-and.png
# An error occurred while downloading x-raw-image:///dcc24370fb5b1bdcd69141acde3984090d5f8b23c77b8fc22daf2c9811351218: No connection adapters were found for 'x-raw-image:///dcc24370fb5b1bdcd69141acde3984090d5f8b23c77b8fc22daf2c9811351218'
# Failed to download image from https://www.researchgate.net/publication/347308677/figure/fig3/AS:11431281173800372@1689045811329/Results-of-laser-treatment-of-conglobate-acne-with-concomitant-oral-isotretinoin-A-face.png
# Failed to download image from https://www.researchgate.net/publication/278717786/figure/fig4/AS:347990687535107@1459978853295/After-two-months-of-treatment-extensive-scars-on-the-back.png
# An error occurred while downloading x-raw-image:///964449b90777858c4ccdf6f309e7d0babc908cbd34a7e565a715d218441afc26: No connection adapters were found for 'x-raw-image:///964449b90777858c4ccdf6f309e7d0babc908cbd34a7e565a715d218441afc26'
# Failed to download image from https://www.researchgate.net/profile/Priscila-Giavedoni/publication/259805406/figure/fig2/AS:282020128280589@1444250246776/Acne-fulminans-Initial-presentation-with-draining-pustules-and-crusted-papules-and_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/10917809/figure/fig7/AS:394429870428169@1471050817335/Severe-acne-papulopustulosa-in-a-21-year-old-male-patient-before-left-and-after-a.png
# Failed to download image from https://www.researchgate.net/profile/Bodo-Melnik/publication/6529492/figure/fig2/AS:272593299177478@1442002715574/Acne-papulopustulosa-induced-by-anabolic-androgenic-steroids_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Jose-Solis-Herruzo/publication/6508933/figure/fig1/AS:601666877411350@1520459970614/Gluteal-region-with-multiple-nodular-lesions-and-scarring-areas-Fig-2-MRI-a-left_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/362206485/figure/fig3/AS:1183935702798336@1659283676228/Acne-conglobata-and-knee-arthritis-after-recombinant-human-TNF-a-receptor-IIIgG-Fc_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/259367699/figure/fig1/AS:214262774538241@1428095634517/Presence-of-pustules-nodules-and-crusts-on-face-predominantly-in-the-malar-region_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/6529492/figure/fig2/AS:272593299177478@1442002715574/Acne-papulopustulosa-induced-by-anabolic-androgenic-steroids.png
# Failed to download image from https://www.researchgate.net/publication/315849834/figure/fig3/AS:1086521419534361@1636058301754/Acne-fulminans-after-28-days-of-oral-prednisone-and-systemic-antimicrobial-regimen.jpg
# Failed to download image from https://www.researchgate.net/publication/230671209/figure/fig1/AS:601620823953446@1520448990573/Acne-fulminans-Hemorrhagic-ulcerations-with-purulent-crust-scattered-on-the-back-and-neck.png
# Failed to download image from https://www.researchgate.net/publication/330735524/figure/fig1/AS:11431281143168643@1681228603338/a-Patients-right-axilla-at-initial-presentation-and-b-patients-left-shoulder-at_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/259367699/figure/fig1/AS:214262774538241@1428095634517/Presence-of-pustules-nodules-and-crusts-on-face-predominantly-in-the-malar-region.png
# Failed to download image from https://www.researchgate.net/publication/269717667/figure/fig8/AS:267920802578441@1440888705172/Clinical-features-of-patients-with-the-association-of-pyoderma-gangrenosum-acne-and.png
# Failed to download image from https://www.researchgate.net/publication/366329010/figure/fig3/AS:11431281124853999@1678121541624/Cutaneous-signs-of-SAPHO-and-PFAPA-a-SAPHO-acne-fulminans-on-the-upper-trunk-A-and_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/258281435/figure/fig1/AS:484507557076994@1492527012001/A-Chronic-severe-nodulocystic-acne-on-face-with-severe-sinus-tracts-and-depressed.png
# An error occurred while downloading x-raw-image:///7bf3ac9113b29083f022346fb0cb582ecee96a7583dae7d69447b71aa97b221a: No connection adapters were found for 'x-raw-image:///7bf3ac9113b29083f022346fb0cb582ecee96a7583dae7d69447b71aa97b221a'
# An error occurred while downloading x-raw-image:///8df96bf8650420e97de5cc907713a3004ccb2e2a9092587ca552ac65bd59d135: No connection adapters were found for 'x-raw-image:///8df96bf8650420e97de5cc907713a3004ccb2e2a9092587ca552ac65bd59d135'
# Failed to download image from https://www.researchgate.net/publication/370380163/figure/fig3/AS:11431281154363488@1682775677958/Complete-healing-of-vesiculo-bullae_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/332541583/figure/fig1/AS:768657722454024@1560273690897/A-Hidradenitis-suppurativa-on-the-patients-back-B-Dissecting-cellulitis-of-the_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Oleg-Akilov/publication/264390398/figure/fig3/AS:434861036052483@1480690358741/Patient-nine-moderate-acne-a-at-baseline-GAGS26-b-at-3-months-after-ALA-PDT.png
# Failed to download image from https://www.researchgate.net/publication/321687273/figure/fig1/AS:963567192903684@1606743729662/c-Forehead-lesions-at-3-months-postadalimumab-therapy.png
# Failed to download image from https://www.researchgate.net/publication/8163563/figure/fig1/AS:601638020608002@1520453090901/Acne-treatment-algorithm-suggested-by-Gollnick-et-al-2003-5-Reprinted-from-the.png
# Failed to download image from https://www.researchgate.net/publication/225041737/figure/fig4/AS:638065194332160@1529138005338/Sample-user-data-showing-examples-of-several-heuristics.png
# Failed to download image from https://www.researchgate.net/profile/Hessel-Van-Der-Zee/publication/26659261/figure/fig3/AS:667218908041227@1536088792795/Acne-conglobata-on-the-back-of-a-man_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/321687273/figure/fig2/AS:963567192911875@1606743729781/a-c-aLeft-side-of-the-face-at-the-time-of-presentation-b-Left-side-of-the-face-at-1_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/269719456/figure/fig1/AS:352117194805248@1460962689777/Generalized-prurigo-nodularis-Patient-1-before-A-and-after-B-a-course-of-modified.png
# An error occurred while downloading x-raw-image:///4919c9f51e8fce8890351ba94309b74e6594e9d36c2eecb36e3a4ebfcf130ed2: No connection adapters were found for 'x-raw-image:///4919c9f51e8fce8890351ba94309b74e6594e9d36c2eecb36e3a4ebfcf130ed2'
# Failed to download image from https://www.researchgate.net/publication/315849834/figure/fig3/AS:1086521419534361@1636058301754/Acne-fulminans-after-28-days-of-oral-prednisone-and-systemic-antimicrobial-regimen_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/301247928/figure/fig2/AS:519014124605440@1500754018392/Acne-pustolosa-before-A-and-after-2-months-of-therapy-with-adalimumab-B-Back.png
# Failed to download image from https://www.researchgate.net/publication/283493289/figure/fig1/AS:550559078141952@1508274921370/Patient-1-close-up-view-of-the-occipital-scalp-with-scarring-alopecia-pustules-and.png
# Failed to download image from https://www.researchgate.net/publication/7070338/figure/fig1/AS:601618814869515@1520448511442/Nodular-lesions-and-sinus-tract-on-the-face-before-etanercept-treatment-a-b-and-the.png
# Failed to download image from https://www.researchgate.net/publication/327596559/figure/fig1/AS:670799430156294@1536942455349/Extensive-facial-papules-nodules-and-cystic-lesions_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/327596559/figure/fig1/AS:670799430156294@1536942455349/Extensive-facial-papules-nodules-and-cystic-lesions.png
# An error occurred while downloading x-raw-image:///5c64b8ad12a8e48292c8cc5ad8f4a5b15a566adff74922f0057dfb1cbd986e90: No connection adapters were found for 'x-raw-image:///5c64b8ad12a8e48292c8cc5ad8f4a5b15a566adff74922f0057dfb1cbd986e90'
# Failed to download image from https://www.researchgate.net/publication/361191663/figure/fig5/AS:11431281173871989@1689049497757/New-onset-of-acne-in-facial-mask-users_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/230671209/figure/tbl1/AS:601620823937052@1520448990652/Differential-diagnosis-of-acne-fulminans-rosacea-fulminans-and-acne-conglobata_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/303988656/figure/fig32/AS:555857000833033@1509538044397/Acne-conglobata-106-Figure-43-Acne-nodulo-kystique-du-dos-105.png
# Failed to download image from https://www.researchgate.net/publication/362206485/figure/fig1/AS:1183935702794240@1659283676072/Acne-conglobata-A-cutis-verticis-gyrata-CVG-B-and-knee-arthritis-C-before_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/8374455/figure/fig1/AS:277841817161744@1443254059765/Phenotype-of-patient-Scarring-alopecia-of-scalp-from-combination-of-disease-process-and.png
# Failed to download image from https://www.researchgate.net/profile/Daniel-Branisteanu/publication/286990231/figure/fig1/AS:898060896989184@1591125811211/Extensive-nodulocystic-and-ulcerative-necrotic-lesions-dorsal-thorax_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/242136618/figure/fig1/AS:392817697411074@1470666445838/Region-glutea-con-multiples-lesiones-modulares-y-zonas-cicatri-ciales.png
# Failed to download image from https://www.researchgate.net/profile/Anatoli-Freiman/publication/50376410/figure/fig3/AS:651879541399554@1532431602217/Grade-IV-severe-acne-showing-many-large-inflamed-nodules-and-pustules-as-well-as_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Marimar-Saez-De-Ocariz/publication/327583983/figure/fig5/AS:669838326382600@1536713310626/Figura-5-Acne-severo-Papulas-pustulas-y-nodulos_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/321687273/figure/fig2/AS:963567192911875@1606743729781/a-c-aLeft-side-of-the-face-at-the-time-of-presentation-b-Left-side-of-the-face-at-1.png
# Failed to download image from https://www.researchgate.net/publication/257813446/figure/fig1/AS:392765612544030@1470654027743/A-Multiple-papulo-pustules-and-nodules-in-a-wedge-shaped-area-on-the-upper-back-neck.png
# Failed to download image from https://www.researchgate.net/publication/356847100/figure/fig1/AS:1098777641402370@1638980412607/Pyoderma-gangrenosum-PG-lesions-and-endoscopy-findings-A-B-Lesions-identified-on_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/349142216/figure/fig1/AS:989296605544450@1612878099672/Fig-1-Skin-lesions-during-the-hospitalization.jpg
# Failed to download image from https://www.researchgate.net/publication/313843797/figure/fig2/AS:613976396279812@1523394788566/Physical-findings-A-On-admission-the-patient-had-multiple-erythematous-follicular.png
# Failed to download image from https://www.researchgate.net/publication/340833756/figure/fig1/AS:11431281173854540@1689056475684/Clinical-image-of-SAPHO-HS-patient-affected-even-by-severe-acne-of-the-trunk-and-neck_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/258281435/figure/fig1/AS:484507557076994@1492527012001/A-Chronic-severe-nodulocystic-acne-on-face-with-severe-sinus-tracts-and-depressed_Q320.jpg
# An error occurred while downloading x-raw-image:///6d786b5d37d86031f5bfb9634cf04cb23144ccbea055a650b6222df97a9ce2c7: No connection adapters were found for 'x-raw-image:///6d786b5d37d86031f5bfb9634cf04cb23144ccbea055a650b6222df97a9ce2c7'
# Failed to download image from https://www.researchgate.net/publication/365101502/figure/fig1/AS:11431281104296597@1669997779971/A-Clustered-erythematous-papules-on-the-central-upper-back-3-months-prior-to.png
# Failed to download image from https://www.researchgate.net/publication/264390398/figure/fig3/AS:434861036052483@1480690358741/Patient-nine-moderate-acne-a-at-baseline-GAGS26-b-at-3-months-after-ALA-PDT.png
# Failed to download image from https://www.researchgate.net/publication/268236070/figure/fig1/AS:669482838134793@1536628555738/Acnee-conglobata-la-un-pacient-cu-boala-Verneuil-Acne-conglobata-to-a-patient-with.ppm
# Failed to download image from https://www.researchgate.net/publication/346073719/figure/fig5/AS:960545175896066@1606023224648/Complications-of-acne_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/344421312/figure/fig2/AS:942224053383178@1601655128119/a-27-year-old-obese-man-with-DcS-underwent-debridement-of-all-hair-bearing-scalp-a-and.ppm
# Failed to download image from https://www.researchgate.net/publication/51607004/figure/fig1/AS:305882199019523@1449939407369/Clinical-and-histopathological-views-a-Raised-reddish-plaque-with-purulent-draining.png
# An error occurred while downloading x-raw-image:///b82a3c6d105f14ce6bc8adafa65d372174a168f95386506d4f2b2045052415d5: No connection adapters were found for 'x-raw-image:///b82a3c6d105f14ce6bc8adafa65d372174a168f95386506d4f2b2045052415d5'
# Failed to download image from https://www.researchgate.net/publication/321269395/figure/fig1/AS:564991201734656@1511715807778/Lesions-of-steatocystoma-multiplex-in-mother.png
# Failed to download image from https://www.researchgate.net/profile/Nobuyuki-Nishimori/publication/344255905/figure/fig1/AS:1077346073354242@1633870728283/Clinical-features-of-the-proband-and-the-pedigree-of-the-familial-hidradenitis.ppm
# Failed to download image from https://www.researchgate.net/publication/315052166/figure/fig1/AS:472132703526912@1489576616653/Infantile-acne-an-8-month-old-girl-presented-with-closed-comedones-and-inflammatory.png
# Failed to download image from https://www.researchgate.net/profile/Marija-Jelusic/publication/332872748/figure/tbl1/AS:894631063592963@1590308075600/Clinical-and-laboratory-features-of-patients-with-SAPHO-syndrome-and-CRMO_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/230671209/figure/fig2/AS:601620823957541@1520448990618/Patient-after-21-days-using-oral-prednisone-1mg-kg-daily-and-dapsone-100-mg-daily_Q320.jpg
# An error occurred while downloading x-raw-image:///e6c9e6cf4515808af5ba67da5d1dbe0a40efead8d3f58b4599098b73e1fb445c: No connection adapters were found for 'x-raw-image:///e6c9e6cf4515808af5ba67da5d1dbe0a40efead8d3f58b4599098b73e1fb445c'
# Failed to download image from https://www.researchgate.net/publication/281679934/figure/fig2/AS:333796663676929@1456594734229/Localized-chloracne-Numerous-black-noninflammatory-open-comedones-exclusively-in-the.png
# Failed to download image from https://www.researchgate.net/profile/Linda-Birnbaum/publication/7327824/figure/fig2/AS:277717200195585@1443224348105/Chloracne-and-hyperpigmentation-in-a-child-from-Seveso-Italy-exposed-to-2-3-7-8-TCDD_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/304619770/figure/fig3/AS:391132958740542@1470264772468/Clinical-manifestation-of-dioxin-induced-chloracne-The-disorder-is-characterized-by.png
# Failed to download image from https://www.researchgate.net/publication/7327824/figure/fig2/AS:277717200195585@1443224348105/Chloracne-and-hyperpigmentation-in-a-child-from-Seveso-Italy-exposed-to-2-3-7-8-TCDD.png
# Failed to download image from https://www.researchgate.net/publication/26703038/figure/fig2/AS:601620396122116@1520448888244/Example-of-TCDD-induced-chloracne-The-photograph-shows-the-ear-of-a-patient-at.png
# Failed to download image from https://www.researchgate.net/publication/263477360/figure/fig2/AS:336449523208192@1457227225030/Severe-chloracne-in-Yusho-patients-oral-intoxication-of-a-high-concentration-of.png
# Failed to download image from https://www.researchgate.net/publication/259956006/figure/fig1/AS:986407849967619@1612189366365/Squamous-cell-carcinoma-The-patient-initially-presented-with-chloracne-and-a-recurrent.ppm
# Failed to download image from https://www.researchgate.net/publication/304619770/figure/fig3/AS:391132958740542@1470264772468/Clinical-manifestation-of-dioxin-induced-chloracne-The-disorder-is-characterized-by_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/10917807/figure/fig5/AS:667085919223819@1536057085985/Pomade-acne-Fig-7-Chloracne-Fig-8-Naevoid-acne.jpg
# Failed to download image from https://www.researchgate.net/publication/281679934/figure/fig1/AS:333796663676928@1456594734200/Localized-chloracne-The-patients-clinical-appearance-with-evidence-of-gauze-dressing.png
# Failed to download image from https://www.researchgate.net/profile/Benjamin-Kaffenberger/publication/281679934/figure/fig2/AS:333796663676929@1456594734229/Localized-chloracne-Numerous-black-noninflammatory-open-comedones-exclusively-in-the_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/348918967/figure/fig4/AS:1030449346392064@1622689677111/Chloracne-Farmer-from-the-Tiete-river-valley-with-extensive-papulopustular-eruption-with.jpg
# Failed to download image from https://www.researchgate.net/profile/Tracey-Bradshaw/publication/26703038/figure/fig2/AS:601620396122116@1520448888244/Example-of-TCDD-induced-chloracne-The-photograph-shows-the-ear-of-a-patient-at_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Andrew-Kochuba/publication/259956006/figure/fig1/AS:986407849967619@1612189366365/Squamous-cell-carcinoma-The-patient-initially-presented-with-chloracne-and-a-recurrent_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/10917809/figure/fig2/AS:394429870428162@1471050817121/Pomade-acne-Fig-7-Chloracne-Fig-8-Naevoid-acne.png
# Failed to download image from https://www.researchgate.net/publication/318791237/figure/fig1/AS:522192552239104@1501511814207/Chloracne-lesions-on-trunk-Comedone-like-lesions-combined-with-skin-color-anomaly-on_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/318791237/figure/fig1/AS:522192552239104@1501511814207/Chloracne-lesions-on-trunk-Comedone-like-lesions-combined-with-skin-color-anomaly-on.png
# Failed to download image from https://www.researchgate.net/profile/Vidal-Junior/publication/348918967/figure/fig4/AS:1030449346392064@1622689677111/Chloracne-Farmer-from-the-Tiete-river-valley-with-extensive-papulopustular-eruption-with_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Hiroshi-Uchi/publication/263477360/figure/fig2/AS:336449523208192@1457227225030/Severe-chloracne-in-Yusho-patients-oral-intoxication-of-a-high-concentration-of_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/7327824/figure/fig1/AS:277717191807011@1443224346856/President-Viktor-Yushchenko-of-Ukraine-before-and-after-dioxin-poisoning-with.png
# Failed to download image from https://www.researchgate.net/publication/282646002/figure/tbl1/AS:613918049316870@1523380877457/Chloracne-MADISH-score-a-MADISH-scoring-system.png
# Failed to download image from https://www.researchgate.net/profile/Elizabeth-Eady/publication/10917809/figure/fig2/AS:394429870428162@1471050817121/Pomade-acne-Fig-7-Chloracne-Fig-8-Naevoid-acne_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Mark-Graham-14/publication/258102200/figure/fig9/AS:201527500251152@1425059308679/Development-of-the-chloracne-phenotype-is-not-a-direct-result-of-AhR-down-regulation-A.png
# Failed to download image from https://www.researchgate.net/publication/49701740/figure/fig4/AS:601623520899108@1520449633749/Chloracne-in-the-mouse-A-Skin-from-a-control-male-B6C3F1-mouse-in-the-2-year-NTP-study.png
# Failed to download image from https://www.researchgate.net/profile/Sudarshan-Kurwadkar/publication/338959752/figure/fig5/AS:903616525250562@1592450376975/Significant-human-health-consequences-of-exposure-to-dioxin_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/304619770/figure/fig2/AS:391115825008644@1470260687173/Arsenic-induced-skin-diseases-chronic-skin-exposure-to-arsenic-induce-palmoplantar_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/26661614/figure/fig2/AS:669163697737738@1536552466973/The-effects-of-dioxin-poisoning-on-the-skin-Photographs-of-Victor-Yuschenko-before.ppm
# Failed to download image from https://www.researchgate.net/publication/348440260/figure/fig2/AS:979594706423809@1610564986601/Excessive-activation-of-aryl-hydrocarbon-receptor-AHR-by-dioxins-induces-chloracne-and.ppm
# Failed to download image from https://www.researchgate.net/publication/258635105/figure/fig5/AS:297393577840643@1447915562431/Non-chloracnegen-AhR-agonists-These-AhR-agonists-do-not-induce-the-cutaneous-syndrome.png
# Failed to download image from https://www.researchgate.net/publication/317913780/figure/fig1/AS:513574411542528@1499457089824/Skin-lesions-and-histopathology-of-worker-B-a-hyperpigmentation-multiple-cysts.png
# Failed to download image from https://www.researchgate.net/profile/Linda-Birnbaum/publication/7327824/figure/fig1/AS:277717191807011@1443224346856/President-Viktor-Yushchenko-of-Ukraine-before-and-after-dioxin-poisoning-with_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Olivier-Sorg/publication/282646002/figure/tbl1/AS:613918049316870@1523380877457/Chloracne-MADISH-score-a-MADISH-scoring-system_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/224581202/figure/fig1/AS:484714759888896@1492576412652/A-victim-of-the-cooking-oil-contamination-with-polychlorinated-biphenyls-Yu-Cheng_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/304619770/figure/fig4/AS:391295370579975@1470303494568/Schematic-overview-of-EDCs-on-skin-structure-and-skin-cells_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/12741300/figure/tbl4/AS:601608635310081@1520446084689/Health-effects-associated-with-exposure-to-TCDD-and-body-burdens-in-humans.png
# Failed to download image from https://www.researchgate.net/profile/Susan_Elmore2/publication/49701740/figure/fig4/AS:601623520899108@1520449633749/Chloracne-in-the-mouse-A-Skin-from-a-control-male-B6C3F1-mouse-in-the-2-year-NTP-study_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/258102200/figure/fig9/AS:201527500251152@1425059308679/Development-of-the-chloracne-phenotype-is-not-a-direct-result-of-AhR-down-regulation-A.png
# Failed to download image from https://www.researchgate.net/publication/324361907/figure/fig1/AS:619919712473089@1524811785990/A-43-year-old-man-after-15-years-exposure-to-PCBs-in-their-manufacture-Comedones-can-be.png
# Failed to download image from https://www.researchgate.net/publication/224581202/figure/fig2/AS:667589030191115@1536177036820/A-baby-born-to-a-polychlorinated-biphenyls-intoxicated-mother-in-Taiwan-during-the_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Rajeev-K-Singla/publication/264710169/figure/tbl3/AS:614091336990728@1523422192682/continued_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/348440260/figure/fig2/AS:979594706423809@1610564986601/Excessive-activation-of-aryl-hydrocarbon-receptor-AHR-by-dioxins-induces-chloracne-and_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Scott-Masten-2/publication/13683915/figure/tbl1/AS:601761073082390@1520482428444/the-average-dioxin-exposure-from-environmental-sources-results-in-tissue-lipid-levels_Q320.jpg
# Failed to download image from https://www.researchgate.net/publication/252636652/figure/fig1/AS:669994157342725@1536750463113/TEQ-and-PCB-Levels-and-Affected-Symptoms-in-Human-and-Monkey.ppm
# Failed to download image from https://www.researchgate.net/publication/317913780/figure/fig1/AS:513574411542528@1499457089824/Skin-lesions-and-histopathology-of-worker-B-a-hyperpigmentation-multiple-cysts_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Olivier-Sorg/publication/43355209/figure/fig1/AS:601768723505173@1520484252282/Diagram-illustrating-the-mode-of-action-of-dioxin-like-compounds-Arnt-AhR-nuclear_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Olivier-Sorg/publication/258635105/figure/fig5/AS:297393577840643@1447915562431/Non-chloracnegen-AhR-agonists-These-AhR-agonists-do-not-induce-the-cutaneous-syndrome_Q320.jpg
# Failed to download image from https://www.researchgate.net/profile/Mark-Graham-14/publication/258102200/figure/fig9/AS:201527500251152@1425059308679/Development-of-the-chloracne-phenotype-is-not-a-direct-result-of-AhR-down-regulation-A_Q320.jpg
# ...
# An error occurred while downloading x-raw-image:///9336086ebf4cdbee810964297b639a4a7254a996c2319662abb87f200675a41b: No connection adapters were found for 'x-raw-image:///9336086ebf4cdbee810964297b639a4a7254a996c2319662abb87f200675a41b'
# An error occurred while downloading x-raw-image:///8a45ca5a625e9ae14614f0eb21f0290f4ec67c0032cd9a7ead82a1b059561f2d: No connection adapters were found for 'x-raw-image:///8a45ca5a625e9ae14614f0eb21f0290f4ec67c0032cd9a7ead82a1b059561f2d'
# An error occurred while downloading x-raw-image:///bcfb1f1b802dd582dce50d91257639965297ac430a5dd8e280bdf028c864c880: No connection adapters were found for 'x-raw-image:///bcfb1f1b802dd582dce50d91257639965297ac430a5dd8e280bdf028c864c880'
# An error occurred while downloading x-raw-image:///4e870edba7681873cadfba486d32d80ea11450cabb69e79a0bdfdcc3f744085b: No connection adapters were found for 'x-raw-image:///4e870edba7681873cadfba486d32d80ea11450cabb69e79a0bdfdcc3f744085b'
# An error occurred while downloading x-raw-image:///eddbd0a946dc2ee6e2085b9a77d98c293171a8b9217a9e8f886a2dc4ac17e9ac: No connection adapters were found for 'x-raw-image:///eddbd0a946dc2ee6e2085b9a77d98c293171a8b9217a9e8f886a2dc4ac17e9ac'
# An error occurred while downloading x-raw-image:///e2d545c66043df986ee1c84c1f146f478ab19a985b1bfff8e04dbfc6e26cf962: No connection adapters were found for 'x-raw-image:///e2d545c66043df986ee1c84c1f146f478ab19a985b1bfff8e04dbfc6e26cf962'
# An error occurred while downloading x-raw-image:///65e0c85046b46b6125be1d6a412005a54f5c19ff30f54da60d6a16e3572e0300: No connection adapters were found for 'x-raw-image:///65e0c85046b46b6125be1d6a412005a54f5c19ff30f54da60d6a16e3572e0300'
# An error occurred while downloading x-raw-image:///20db87a87f121508979ef1b201b9b911515bf952edb4437b8e973e8986ae065c: No connection adapters were found for 'x-raw-image:///20db87a87f121508979ef1b201b9b911515bf952edb4437b8e973e8986ae065c'
# An error occurred while downloading x-raw-image:///28a99c10ed5b9cbc4e72100afb19c3ec3e3d7c32c9ad85614763ed28a2093a2c: No connection adapters were found for 'x-raw-image:///28a99c10ed5b9cbc4e72100afb19c3ec3e3d7c32c9ad85614763ed28a2093a2c'
# An error occurred while downloading x-raw-image:///4a46159296a4df25985ec99cbac26d2312b1b74b3eed493693893800223454fa: No connection adapters were found for 'x-raw-image:///4a46159296a4df25985ec99cbac26d2312b1b74b3eed493693893800223454fa'
# An error occurred while downloading x-raw-image:///0299df66658cefb8806c2e551ae1b6f48dc1e41318d240e0166128875335b702: No connection adapters were found for 'x-raw-image:///0299df66658cefb8806c2e551ae1b6f48dc1e41318d240e0166128875335b702'
# An error occurred while downloading x-raw-image:///da8f69daac48f837925a740a48eef346dbb5609734db15878f4f154ddf6e1ca4: No connection adapters were found for 'x-raw-image:///da8f69daac48f837925a740a48eef346dbb5609734db15878f4f154ddf6e1ca4'
# An error occurred while downloading x-raw-image:///d9e5e96b9f36599c3740cf82c6fe4c0f20f4a6c1b090648e84ca0836a7ce0c0a: No connection adapters were found for 'x-raw-image:///d9e5e96b9f36599c3740cf82c6fe4c0f20f4a6c1b090648e84ca0836a7ce0c0a'
# An error occurred while downloading x-raw-image:///36852e8b2269c002493e604af7f05d7513e07cce9f1fa0f7b0ae8816de731f7e: No connection adapters were found for 'x-raw-image:///36852e8b2269c002493e604af7f05d7513e07cce9f1fa0f7b0ae8816de731f7e'
# An error occurred while downloading x-raw-image:///11ca4ff138896c2b5999ea8ce795c364b18b197abe5f2d65a72f1c110ad87910: No connection adapters were found for 'x-raw-image:///11ca4ff138896c2b5999ea8ce795c364b18b197abe5f2d65a72f1c110ad87910'
# An error occurred while downloading x-raw-image:///fc36ff6e5d7bfb7ae77900f6485726ebfa729b4b20d1b54a8f529f52775eea59: No connection adapters were found for 'x-raw-image:///fc36ff6e5d7bfb7ae77900f6485726ebfa729b4b20d1b54a8f529f52775eea59'
# An error occurred while downloading x-raw-image:///35780133f7fdcd034518098450b0235609ba6dbaaa647cf5da92582013300973: No connection adapters were found for 'x-raw-image:///35780133f7fdcd034518098450b0235609ba6dbaaa647cf5da92582013300973'
# An error occurred while downloading x-raw-image:///33b861941505fbae8db4c5ff62be78ce6484252ea7a8124300cef17714843d74: No connection adapters were found for 'x-raw-image:///33b861941505fbae8db4c5ff62be78ce6484252ea7a8124300cef17714843d74'
# An error occurred while downloading x-raw-image:///d03247f899bfb3ef6d61a252d0932b742328611d12385b7d8641d6b7b80d700b: No connection adapters were found for 'x-raw-image:///d03247f899bfb3ef6d61a252d0932b742328611d12385b7d8641d6b7b80d700b'
# An error occurred while downloading x-raw-image:///71ded9ed21256f006281ea46c91094df30b54d674a37a63f17f8250ed4846088: No connection adapters were found for 'x-raw-image:///71ded9ed21256f006281ea46c91094df30b54d674a37a63f17f8250ed4846088'
# An error occurred while downloading x-raw-image:///919c91a263be7e1244c2490760806bf312d4d7fa7fff5fb110362aae91f7b412: No connection adapters were found for 'x-raw-image:///919c91a263be7e1244c2490760806bf312d4d7fa7fff5fb110362aae91f7b412'
# An error occurred while downloading x-raw-image:///811eadf558d0fba0f5ad8b2dfbd5b73fb6bb8aae811e4801742bbfde663f5c4d: No connection adapters were found for 'x-raw-image:///811eadf558d0fba0f5ad8b2dfbd5b73fb6bb8aae811e4801742bbfde663f5c4d'
# An error occurred while downloading x-raw-image:///e90582119e8e22c8a2857084d132a602970669fe4dac9db408c32c07c03a874b: No connection adapters were found for 'x-raw-image:///e90582119e8e22c8a2857084d132a602970669fe4dac9db408c32c07c03a874b'
# An error occurred while downloading x-raw-image:///17f00a35ccdee4252f49e4cad2f59aa8cf4f7ce25720e8f7b80b2d38e69bee9c: No connection adapters were found for 'x-raw-image:///17f00a35ccdee4252f49e4cad2f59aa8cf4f7ce25720e8f7b80b2d38e69bee9c'
# An error occurred while downloading x-raw-image:///aefc573b53e494e706d797ead2d8005fd6874f80644f505e28bd15ce95594607: No connection adapters were found for 'x-raw-image:///aefc573b53e494e706d797ead2d8005fd6874f80644f505e28bd15ce95594607'
# An error occurred while downloading x-raw-image:///e132864effe4fd2ddf8d026cc893d404ce578ac09e2236b595db4657d100760c: No connection adapters were found for 'x-raw-image:///e132864effe4fd2ddf8d026cc893d404ce578ac09e2236b595db4657d100760c'
# An error occurred while downloading x-raw-image:///c86a55e789f7dfce3deed3b4238ed3fdebb44073129efba26ccc1cf002953fd0: No connection adapters were found for 'x-raw-image:///c86a55e789f7dfce3deed3b4238ed3fdebb44073129efba26ccc1cf002953fd0'
# An error occurred while downloading x-raw-image:///6b8f4194e0e9ffe80f707f4e3b82e5f0ff5caf39969f89b2977c45925449ebe6: No connection adapters were found for 'x-raw-image:///6b8f4194e0e9ffe80f707f4e3b82e5f0ff5caf39969f89b2977c45925449ebe6'
# An error occurred while downloading x-raw-image:///a473f0e20fa2674f24a139dd50e954af1c7936464f2bd9722ec669c193fc46e4: No connection adapters were found for 'x-raw-image:///a473f0e20fa2674f24a139dd50e954af1c7936464f2bd9722ec669c193fc46e4'
# An error occurred while downloading x-raw-image:///23191f6c547934f92b6020d7b8fa31ea3539f642e442fe8573c8541e59625427: No connection adapters were found for 'x-raw-image:///23191f6c547934f92b6020d7b8fa31ea3539f642e442fe8573c8541e59625427'
# An error occurred while downloading x-raw-image:///cac03371511d52f1fe572ec6f801931044b85f77987a763e5234397268868e6d: No connection adapters were found for 'x-raw-image:///cac03371511d52f1fe572ec6f801931044b85f77987a763e5234397268868e6d'
# An error occurred while downloading x-raw-image:///792d662db6667fe14832fc20bd9b3fd9b14d5221b9cbbe900625af9ce52f0415: No connection adapters were found for 'x-raw-image:///792d662db6667fe14832fc20bd9b3fd9b14d5221b9cbbe900625af9ce52f0415'
# An error occurred while downloading x-raw-image:///268bd35e53d41ad6d60e780a82d80b1ce6e0b1875c0874ab5d1f698953104ec2: No connection adapters were found for 'x-raw-image:///268bd35e53d41ad6d60e780a82d80b1ce6e0b1875c0874ab5d1f698953104ec2'
# An error occurred while downloading x-raw-image:///d2b9d09d5db58c85d498df384a442ba21ee4c9e39c547eb3130c61ba8499e4e1: No connection adapters were found for 'x-raw-image:///d2b9d09d5db58c85d498df384a442ba21ee4c9e39c547eb3130c61ba8499e4e1'
# An error occurred while downloading x-raw-image:///d864f09f2d1f09815c3489802501da131b3b2b4b1bda68bb01e2263959a50b47: No connection adapters were found for 'x-raw-image:///d864f09f2d1f09815c3489802501da131b3b2b4b1bda68bb01e2263959a50b47'
# An error occurred while downloading x-raw-image:///e0534138ffb97967772aa5227a4b250841e2662131dfb8fe3e20b7300ae2583c: No connection adapters were found for 'x-raw-image:///e0534138ffb97967772aa5227a4b250841e2662131dfb8fe3e20b7300ae2583c'
# An error occurred while downloading x-raw-image:///664b373688ad58a77a2a4c3c4182edc05feb6fefdc9a7c1f647c1f7458549efd: No connection adapters were found for 'x-raw-image:///664b373688ad58a77a2a4c3c4182edc05feb6fefdc9a7c1f647c1f7458549efd'
# An error occurred while downloading x-raw-image:///46469fceef5eb123bccbe7c166ffd3fdcef213bb965ab1f5676d744e374de1d1: No connection adapters were found for 'x-raw-image:///46469fceef5eb123bccbe7c166ffd3fdcef213bb965ab1f5676d744e374de1d1'
# An error occurred while downloading x-raw-image:///91c94c332db34d15e46e94cab46294730fb7850aafd329831bd1ad1de1b22e9c: No connection adapters were found for 'x-raw-image:///91c94c332db34d15e46e94cab46294730fb7850aafd329831bd1ad1de1b22e9c'
# An error occurred while downloading x-raw-image:///e20a441f56efda72e62cfd54b367e3c334cf90ac134f3866e6dfb791cf8e2f71: No connection adapters were found for 'x-raw-image:///e20a441f56efda72e62cfd54b367e3c334cf90ac134f3866e6dfb791cf8e2f71'
# An error occurred while downloading x-raw-image:///bdcd548655772208f76ee6d38a0cb0af23c383cb6b45fac08d8dc860ea635d90: No connection adapters were found for 'x-raw-image:///bdcd548655772208f76ee6d38a0cb0af23c383cb6b45fac08d8dc860ea635d90'
# An error occurred while downloading x-raw-image:///db3329e372761a33b800416db5fd80ef662ad9b4c06664efa6cb6c67e55dd580: No connection adapters were found for 'x-raw-image:///db3329e372761a33b800416db5fd80ef662ad9b4c06664efa6cb6c67e55dd580'
# An error occurred while downloading x-raw-image:///b8b39eb8523151e865b512ffe9d443317ab1782a0fae4ee58a3af4a6e799934a: No connection adapters were found for 'x-raw-image:///b8b39eb8523151e865b512ffe9d443317ab1782a0fae4ee58a3af4a6e799934a'
# An error occurred while downloading x-raw-image:///1cec5b8d265441cb7c7ad9d77742e67cc8f9725fd3a2b6b46c3022b1d9711a8b: No connection adapters were found for 'x-raw-image:///1cec5b8d265441cb7c7ad9d77742e67cc8f9725fd3a2b6b46c3022b1d9711a8b'
# An error occurred while downloading x-raw-image:///e43508730189d3a7ab1f9685789469f799a46ead76ee0ac304a48bbe746ef8b5: No connection adapters were found for 'x-raw-image:///e43508730189d3a7ab1f9685789469f799a46ead76ee0ac304a48bbe746ef8b5'
# An error occurred while downloading x-raw-image:///df0b00cd7683fa0aae3aa5453268606b0a61d768dc544b25cd183eecc132a9f3: No connection adapters were found for 'x-raw-image:///df0b00cd7683fa0aae3aa5453268606b0a61d768dc544b25cd183eecc132a9f3'
# An error occurred while downloading x-raw-image:///86c3cad1a263365de8c5722d32c89529ed928ec1b2ddfb5efd16c0cb131bfdfa: No connection adapters were found for 'x-raw-image:///86c3cad1a263365de8c5722d32c89529ed928ec1b2ddfb5efd16c0cb131bfdfa'
# An error occurred while downloading x-raw-image:///ddef632719e50f6d2a9c01ac10aa2f43b0bd3cfb65d59120acaad9aa77ab00de: No connection adapters were found for 'x-raw-image:///ddef632719e50f6d2a9c01ac10aa2f43b0bd3cfb65d59120acaad9aa77ab00de'
# An error occurred while downloading x-raw-image:///2385b4f78a4e6da1043ac915e5b777016d66b4c3cc011f89efbdb1e945ef84cf: No connection adapters were found for 'x-raw-image:///2385b4f78a4e6da1043ac915e5b777016d66b4c3cc011f89efbdb1e945ef84cf'
# An error occurred while downloading x-raw-image:///070fb0df1802598dd84dbda3078654fbb3c1a99147843b514c9d67f6e3d01992: No connection adapters were found for 'x-raw-image:///070fb0df1802598dd84dbda3078654fbb3c1a99147843b514c9d67f6e3d01992'
# An error occurred while downloading x-raw-image:///16a7b6d41a360ba94d19cd28af4bda49502bc2bfb7939824685751fff48e2a89: No connection adapters were found for 'x-raw-image:///16a7b6d41a360ba94d19cd28af4bda49502bc2bfb7939824685751fff48e2a89'
# An error occurred while downloading x-raw-image:///08c82f20a71ca0dc1e5411affe97a67ca901c52182d623445dcbd572aa232c3c: No connection adapters were found for 'x-raw-image:///08c82f20a71ca0dc1e5411affe97a67ca901c52182d623445dcbd572aa232c3c'
# An error occurred while downloading x-raw-image:///8fa62fcd7543bf06d7e5487e91c4d9a30561422efe5e66c282d1cb5b23faa9d7: No connection adapters were found for 'x-raw-image:///8fa62fcd7543bf06d7e5487e91c4d9a30561422efe5e66c282d1cb5b23faa9d7'
# An error occurred while downloading x-raw-image:///7bb69d5806a1c5d4f8691827723d7d20b29845888bbe87c5cde1d540284a05cf: No connection adapters were found for 'x-raw-image:///7bb69d5806a1c5d4f8691827723d7d20b29845888bbe87c5cde1d540284a05cf'
# An error occurred while downloading x-raw-image:///52902a105114282cc1f871443617aa43909bfe415f71bc6d88761b7434bf1b33: No connection adapters were found for 'x-raw-image:///52902a105114282cc1f871443617aa43909bfe415f71bc6d88761b7434bf1b33'
# An error occurred while downloading x-raw-image:///0e91e923ff7957a77ac3886f2bb8d77fa3f4e44f068f25b8760125f64eb34ec8: No connection adapters were found for 'x-raw-image:///0e91e923ff7957a77ac3886f2bb8d77fa3f4e44f068f25b8760125f64eb34ec8'
# An error occurred while downloading x-raw-image:///1eff0ec1603d5d9661d056455e2839679e36f411109daf5566e9ac57b62e86bd: No connection adapters were found for 'x-raw-image:///1eff0ec1603d5d9661d056455e2839679e36f411109daf5566e9ac57b62e86bd'
# An error occurred while downloading x-raw-image:///b2a248d85c6b4ae1d3bde19d889ff072e19c6ca8967c528d186905acb96b409a: No connection adapters were found for 'x-raw-image:///b2a248d85c6b4ae1d3bde19d889ff072e19c6ca8967c528d186905acb96b409a'
# An error occurred while downloading x-raw-image:///bc1d0fa3dcc0e20595428edd54e9608c163e742d865b0338ff585d18954492c8: No connection adapters were found for 'x-raw-image:///bc1d0fa3dcc0e20595428edd54e9608c163e742d865b0338ff585d18954492c8'
# An error occurred while downloading x-raw-image:///b88a00fbec0d28f0cf9021e5fe0ecb239a6ef531f946616a807ad07168819a6d: No connection adapters were found for 'x-raw-image:///b88a00fbec0d28f0cf9021e5fe0ecb239a6ef531f946616a807ad07168819a6d'
# An error occurred while downloading x-raw-image:///bef5d60b6cc8722a78698185d612db595845d7894a5aa9ea88d3356f4e2cf372: No connection adapters were found for 'x-raw-image:///bef5d60b6cc8722a78698185d612db595845d7894a5aa9ea88d3356f4e2cf372'
# An error occurred while downloading x-raw-image:///324c22557a813a5d68f0e46c223bed95f5928abfc8969d7c7aeb50d5fb939127: No connection adapters were found for 'x-raw-image:///324c22557a813a5d68f0e46c223bed95f5928abfc8969d7c7aeb50d5fb939127'
# An error occurred while downloading x-raw-image:///c4e3b4db9d5fa56e5247b2a94eab08683edf7a1287f097246de2864dad807931: No connection adapters were found for 'x-raw-image:///c4e3b4db9d5fa56e5247b2a94eab08683edf7a1287f097246de2864dad807931'
# An error occurred while downloading x-raw-image:///b2c66d99060ae417022656c1ffe951b5818aa2d042b0ea0023d83a610ed640a2: No connection adapters were found for 'x-raw-image:///b2c66d99060ae417022656c1ffe951b5818aa2d042b0ea0023d83a610ed640a2'
# An error occurred while downloading x-raw-image:///8cd5475dbd41870e79f6fa2961133d3521a885c7a755cf9cd79a1f44efd83969: No connection adapters were found for 'x-raw-image:///8cd5475dbd41870e79f6fa2961133d3521a885c7a755cf9cd79a1f44efd83969'
# An error occurred while downloading x-raw-image:///f73b76f63c0d3e1dcb535996ef292efb8d6a34aa7021c0d6cc1960e4f50ba8cd: No connection adapters were found for 'x-raw-image:///f73b76f63c0d3e1dcb535996ef292efb8d6a34aa7021c0d6cc1960e4f50ba8cd'
# ====================================================================================================
# Completed downloads for: mdedge.com
# ====================================================================================================

# %% [markdown]
# #### 2.3.3.2 Baidu Search Engine URLs

# %%
# Specify range of items to download
start_index = 0
end_index = 236

# Iterate over the specified range of items in the search list
for i in range(start_index, end_index + 1):
    try:
        item = searchManager.search_list[i]
        className = item['label']
        downloadManager.download_baidu_urls_for_item(item)
        print(f"Successfully downloaded all images for item {i} {item['label']}")
        time.sleep(20)
    except IndexError:
        print(f"Index {i} {item['label']} is out of range in the search list")
    except Exception as e:
        print(f"An error occurred while downloading images for item {i} {item['label']}: {e}")
# Out:
# Successfully downloaded all images for item 0 Acne Keloid
# Successfully downloaded all images for item 1 Acne Conglobata
# Successfully downloaded all images for item 2 Chloracne
# Successfully downloaded all images for item 21 Dermatitis Herpetiformis
# Successfully downloaded all images for item 22 Dermatitis, Atopic
# Successfully downloaded all images for item 23 Dermatitis, Photoallergic
# Successfully downloaded all images for item 25 Dermatitis, Phototoxic
# Successfully downloaded all images for item 27 Dermatitis, Occupational
# Successfully downloaded all images for item 28 Dermatitis, Exfoliative
# Successfully downloaded all images for item 29 Dermatitis, Perioral
# Successfully downloaded all images for item 30 Dermatitis, Seborrheic
# Successfully downloaded all images for item 33 Erythema Nodosum
# Successfully downloaded all images for item 36 Serum Sickness
# Successfully downloaded all images for item 37 Stevens-Johnson Syndrome
# Successfully downloaded all images for item 38 Eczema, Dyshidrotic
# Successfully downloaded all images for item 39 Tinea cruris
# Successfully downloaded all images for item 41 Radiodermatitis
# Successfully downloaded all images for item 42 Dermatomyositis
# Successfully downloaded all images for item 43 Erythema Ab Igne
# Successfully downloaded all images for item 44 Erythema Chronicum Migrans
# Successfully downloaded all images for item 51 Tinea Pedis
# Successfully downloaded all images for item 52 Foot Ulcer
# Successfully downloaded all images for item 54 Hirsutism
# Successfully downloaded all images for item 56 Alopecia Areata
# Successfully downloaded all images for item 63 Keratoacanthoma
# Successfully downloaded all images for item 64 Callosities
# Successfully downloaded all images for item 66 Darier Disease
# Successfully downloaded all images for item 71 Ichthyosis Vulgaris
# Successfully downloaded all images for item 72 Ichthyosis, X-Linked
# Successfully downloaded all images for item 77 Keratosis, Seborrheic
# Successfully downloaded all images for item 79 Porokeratosis
# Successfully downloaded all images for item 87 Nails, Ingrown
# Successfully downloaded all images for item 88 Onycholysis
# Successfully downloaded all images for item 89 Onychomycosis
# Successfully downloaded all images for item 90 Steatocystoma Multiplex
# Successfully downloaded all images for item 93 Granuloma Annulare
# Successfully downloaded all images for item 94 Necrobiosis Lipoidica
# Successfully downloaded all images for item 96 Necrolytic Migratory Erythema
# Successfully downloaded all images for item 100 Sunburn
# Successfully downloaded all images for item 102 Xeroderma Pigmentosum
# Successfully downloaded all images for item 104 Cafe-au-Lait Spots
# Successfully downloaded all images for item 105 Acanthosis Nigricans
# Successfully downloaded all images for item 106 LEOPARD Syndrome
# Successfully downloaded all images for item 111 Vitiligo
# Successfully downloaded all images for item 113 Urticaria Pigmentosa
# Successfully downloaded all images for item 114 Prurigo
# Successfully downloaded all images for item 115 Pruritus Ani
# Successfully downloaded all images for item 117 Ecthyma
# Successfully downloaded all images for item 118 Pyoderma Gangrenosum
# Successfully downloaded all images for item 140 Port-Wine Stain
# Successfully downloaded all images for item 150 Pemphigus, Benign Familial
# Successfully downloaded all images for item 153 Porphyria Cutanea Tarda
# Successfully downloaded all images for item 160 Candidiasis, Cutaneous
# Successfully downloaded all images for item 168 Tinea Versicolor
# Successfully downloaded all images for item 172 Erysipelas
# Successfully downloaded all images for item 173 Erythrasma
# Successfully downloaded all images for item 175 Hidradenitis Suppurativa
# Successfully downloaded all images for item 178 Carbuncle
# Successfully downloaded all images for item 179 Impetigo
# Successfully downloaded all images for item 184 Larva Migrans
# Successfully downloaded all images for item 189 Scabies
# Successfully downloaded all images for item 190 Herpes Labialis
# Successfully downloaded all images for item 191 Kaposi Varicelliform Eruption
# Successfully downloaded all images for item 192 Molluscum Contagiosum
# Successfully downloaded all images for item 198 Lichen Nitidus
# Successfully downloaded all images for item 202 Pityriasis Rosea
# Successfully downloaded all images for item 203 Pityriasis Rubra Pilaris
# Successfully downloaded all images for item 204 Arthritis, Psoriatic
# Successfully downloaded all images for item 211 Livedo Reticularis
# Successfully downloaded all images for item 212 Malignant Atrophic Papulosis
# Successfully downloaded all images for item 219 Vasculitis, Leukocytoclastic, Cutaneous
# Successfully downloaded all images for item 221 Blister
# Successfully downloaded all images for item 222 Linear IgA Bullous Dermatosis
# Successfully downloaded all images for item 223 Pemphigoid Gestationis
# Successfully downloaded all images for item 225 Pemphigoid, Bullous
# Successfully downloaded all images for item 227 Mastocytoma, Skin
# Successfully downloaded all images for item 231 Varicose Ulcer
# Successfully downloaded all images for item 235 Fox-Fordyce Disease
# Successfully downloaded all images for item 236 Xanthogranuloma, Juvenile
